# %%
##  to make a connection with database
import pandas as pd
import sqlalchemy
import time
def get_connection():
#     conn_str = 'postgres://hedwig:F9#e*53i@prod-in-mis.cxacyn8xjvlq.ap-south-1.redshift.amazonaws.com:5439/prod'
    conn_str = 'postgres://datascience:H4ugBkV6JNp4wzYj@prod-in-mis.cxacyn8xjvlq.ap-south-1.redshift.amazonaws.com:5439/prod'
    engine = sqlalchemy.create_engine(conn_str) 
    connection = engine.connect()  
    return connection

engine_string = get_connection()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
def run_sql():
    df = pd.read_sql_query(f''' 
SELECT  sum(drawdown_amount) as total_drawdown 

from (

SELECT ld._id, type , loandetail_productcode ,drawdown_amount, event_id, 
(CONVERT_TIMEZONE('Asia/Kolkata', TIMESTAMP 'epoch' + date/1000 * INTERVAL '1 second')) as drawdate
from loan_detail ld left join loan_events le on ld._id=le._id 
where loandetail_productcode LIKE '%PINE%'  and type = 'EventDrawdown'  and   drawdate >='2023-12-08'    


)                                                  
        
        
''', engine_string)  
    return df
#('DISBURSED','OVERDUE' , 'CLOSED' , 'WRITTEN_OFF', 'PRE_CLOSED')  
while True:
    df = run_sql()
    print(df['total_drawdown'][0])
    if df['total_drawdown'][0] >= 29700000.00:
        notify.send(f'Alert now the amount is {df["total_drawdown"][0]}')
        
    time.sleep(120)
# Out:
# 69702161.0
# 69702161.0
# 69702161.0
# 69702161.0
# 69702161.0

# %%
pip install notify_run
# Out:
# ...
#      |████████████████████████████████| 419 kB 20.0 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 41 kB 924 kB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 420 kB 64.6 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 57 kB 647 kB/s
# ...
#      |████████████████████████████████| 58 kB 10.1 MB/s
# ...
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# ...
#   Created wheel for notify-run: filename=notify_run-0.0.14-py3-none-any.whl size=5539 sha256=7e8f1bb0cc6a07d0c9aa06883a9ea24b568f02aa3523ca92a32ecf2d0d9e3236
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/6a/5d/aa/ca5291746905de504351a4232395a9db91bf50c95f20b03fa4
# ...
#   Created wheel for PyQRCode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36245 sha256=9a0411e5f90a1039f9e626bb4d9f89abcec94cddd215ce4db7abbc8da9367ab1
# ...

# %%
pip install notify_run
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# aiobotocore                        1.3.0
# aiohttp                            3.8.1
# aioitertools                       0.7.1
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-project                   0.9.1
# anyio                              3.4.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.9.0
# astropy                            4.1
# async-generator                    1.10
# async-timeout                      4.0.1
# asynctest                          0.13.0
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autofeat                           2.0.10
# ...

# %%
from notify_run import Notify

# %%
notify = Notify()

# %%
notify.register()
# Out:
# Endpoint: https://notify.run/pIJnpm4Fv7YTUpuwVMyp
# To subscribe, open: https://notify.run/c/pIJnpm4Fv7YTUpuwVMyp
# Or scan this QR code:

# %%
notify.send('Hello')
